# %%
import sys
import os

sys.path.append(os.getcwd())
# append the root directory to the sys.path

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### TODO: add gensim to requirements and rebuilt dockerimage

# %%
! pip install gensim
! pip install transformers
! pip install datasets
! pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 28.8 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.1/566.1 kB 100.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 76.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 92.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [transformers] [transformers]ub]
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.5/47.5 MB 266.0 MB/s  0:00:00
# ...

# %%
import os, sys

dataset = 'mustard'
file_name = 'sarcasm_raw_text.pkl'
root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
data_path = os.path.join(root_path, 'data', 'multibench', dataset, file_name)

with open('/home/pliang/multibench/affect/sarcasm.pkl', "rb") as f:
        alldata = pickle.load(f)

    train_keys = list(alldata['train']['id'])
    print(alldata['train']['vision'].shape)

    raw_path = '/home/pliang/multibench/affect/sarcasm_raw_text.pkl'

    new_train_data = bert_version_data(alldata['train'], raw_path, train_keys)

    print(new_train_data['vision'].shape)
    print(new_train_data['audio'].shape)
    print(new_train_data['text'].shape)

# %%
from MultiBench.datasets.affect.get_bert_embedding import get_dataloader


train_dl, val_dl, test_dl = get_dataloader(
    mosei_raw_path,
    data_type="mosei",
    task="regression",
    num_workers=0,
    # if you want fixed shapes:
    max_pad=True,
    max_seq_len=50,
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from MultiBench.datasets.affect.get_bert_embedding import get_dataloader
#       2 import os, sys
#       4 root_path = os.path.abspath(os.path.join(os.getcwd(), '..'))
#
# File /mnt/lts4-dislearn/scratch/home/rizou/lts4-FaP/MultiBench/datasets/affect/get_bert_embedding.py:4
#       2 import torch
#       3 from torch import nn
# ----> 4 from transformers import AutoTokenizer, pipeline, BertModel
#       5 import h5py
#       6 import pickle
#
# ModuleNotFoundError: No module named 'transformers'
