# %% [markdown]
# ### Load and Visualize the _MUsTARD_ dataset

# %%
import sys
import os

sys.path.append(os.getcwd())
# append the root directory to the sys.path

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

# %%
# define necessary imports below
from src.preprocessing.affect_get_data import get_dataloader
# Out:
# /Users/vasilikirizou/miniconda/envs/lts4-fap-env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# ### Load train- validation - test set

# %%
train_data, valid_data, test_robust = get_dataloader('../data/multibench/mustard/sarcasm.pkl', robust_test= False, 
                                                   max_pad= True, task= 'classification', 
                                                   data_type= 'sarcasm', max_seq_len= 40)

# %%
train_data.dataset
# Out:
# [tensor([[ 228.1600,  184.6600, -637.0800,  ..., -473.7200, -475.6200,
#           -478.8900],
#          [ 228.7667,  187.7667, -643.9333,  ..., -467.9667, -469.8167,
#           -473.1000],
#          [ 233.4857,  188.9714, -529.7072,  ..., -470.1714, -469.1071,
#           -469.1071],
#          ...,
#          [   0.0000,    0.0000,    0.0000,  ...,    0.0000,    0.0000,
#              0.0000],
#          [   0.0000,    0.0000,    0.0000,  ...,    0.0000,    0.0000,
#              0.0000],
#          [   0.0000,    0.0000,    0.0000,  ...,    0.0000,    0.0000,
#              0.0000]]),
#  tensor([[   0.0000,    0.0000,    0.0000,  ..., -256.6000, 2309.6001,
#           -254.0300],
#          [   0.0000,    0.0000,    0.0000,  ..., -221.1833, 2153.5500,
#           -218.7833],
#          [   0.0000,    0.0000,    0.0000,  ..., -149.1000, 1917.8214,
#           -145.1000],
#          ...,
#          [   0.0000,    0.0000,    0.0000,  ...,    0.0000,    0.0000,
# ...
